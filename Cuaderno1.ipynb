# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.1.4'

# %%
#tabla = pd.read_csv(r'C:\Users\denny\Downloads\TablaEjemplo.csv')

# %%
#tabla

# %%
#tabla['Nombre']

# %%
#tabla.Edad

# %%
#tabla[['Nombre', 'País']]

# %%
#type(tabla.Nombre)

# %%
#type(tabla[['Nombre', 'País']])

# %%
ventasTotales = pd.read_csv(r'H:\Mi unidad\Análisis de Datos con Pandas y Python\ventasTotales.csv',skiprows=5,sep=';')

# %%
ventasTotales
# Out:
#          Fecha          Vendedor Región           Artículo    Categoría  \
# 0     1/1/2016      Steve Ashton  Norte   Medias Femeninas   Vestimenta
# 1     1/1/2016  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 2     1/1/2016        Sarah Bond    Sur             Gorras   Vestimenta
# 3     1/1/2016   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4     1/1/2016   Desmond Delaney   Este          Chocolate  Comestibles
# ..         ...               ...    ...                ...          ...
# 455  31/1/2016        Sarah Bond    Sur            Bufanda   Vestimenta
# 456  31/1/2016        Dustin Gee   Este          Sandalias   Vestimenta
# 457  31/1/2016        Dustin Gee   Este  Sánguche de Queso  Comestibles
# 458  31/1/2016        Dustin Gee  Norte         Escobillón        Hogar
# 459  31/1/2016  Trevor Snodgrass    Sur          Pepinillo  Comestibles
#
#      Unidades Ganancia
# 0           6    18,00
# 1           8     3,84
# 2           3     6,30
# ...

# %%
ventasTotales.shape
# Out:
# (460, 7)

# %%
ventasTotales.head()
# Out:
#       Fecha          Vendedor Región           Artículo    Categoría  \
# 0  1/1/2016      Steve Ashton  Norte   Medias Femeninas   Vestimenta
# 1  1/1/2016  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 2  1/1/2016        Sarah Bond    Sur             Gorras   Vestimenta
# 3  1/1/2016   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4  1/1/2016   Desmond Delaney   Este          Chocolate  Comestibles
#
#    Unidades Ganancia
# 0         6    18,00
# 1         8     3,84
# 2         3     6,30
# 3         9    14,40
# 4        14     6,72

# %%
ventasTotales.tail()
# Out:
#          Fecha          Vendedor Región           Artículo    Categoría  \
# 455  31/1/2016        Sarah Bond    Sur            Bufanda   Vestimenta
# 456  31/1/2016        Dustin Gee   Este          Sandalias   Vestimenta
# 457  31/1/2016        Dustin Gee   Este  Sánguche de Queso  Comestibles
# 458  31/1/2016        Dustin Gee  Norte         Escobillón        Hogar
# 459  31/1/2016  Trevor Snodgrass    Sur          Pepinillo  Comestibles
#
#      Unidades Ganancia
# 455         6    16,50
# 456        11   115,50
# 457         4     6,40
# 458         8     6,80
# 459         7     2,10

# %%
ventasTotales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460 entries, 0 to 459
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Fecha      460 non-null    object
#  1   Vendedor   460 non-null    object
#  2   Región     460 non-null    object
#  3   Artículo   460 non-null    object
#  4   Categoría  460 non-null    object
#  5   Unidades   460 non-null    int64
#  6   Ganancia   460 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 25.3+ KB

# %%
ventasTotales.Vendedor.value_counts(dropna=False)
# Out:
# Vendedor
# Sarah Bond          86
# Steve Ashton        84
# Desmond Delaney     76
# Trevor Snodgrass    75
# Dustin Gee          70
# Boris Stanford      69
# Name: count, dtype: int64

# %%
ventasTotales.Vendedor.sort_values()
# Out:
# 198      Boris Stanford
# 71       Boris Stanford
# 66       Boris Stanford
# 259      Boris Stanford
# 64       Boris Stanford
#              ...
# 212    Trevor Snodgrass
# 209    Trevor Snodgrass
# 206    Trevor Snodgrass
# 286    Trevor Snodgrass
# 459    Trevor Snodgrass
# Name: Vendedor, Length: 460, dtype: object

# %%
ventasTotales.sort_values(by=['Vendedor','Ganancia'])
# Out:
#          Fecha          Vendedor Región    Artículo    Categoría  Unidades  \
# 93    6/1/2016    Boris Stanford  Norte   Chocolate  Comestibles         2
# 450  31/1/2016    Boris Stanford   Este   Chocolate  Comestibles         3
# 259  18/1/2016    Boris Stanford    Sur   Pepinillo  Comestibles         5
# 25    2/1/2016    Boris Stanford   Este         Pan  Comestibles         4
# 64    5/1/2016    Boris Stanford    Sur         Pan  Comestibles         4
# ..         ...               ...    ...         ...          ...       ...
# 231  15/1/2016  Trevor Snodgrass   Este      Gorras   Vestimenta         4
# 314  21/1/2016  Trevor Snodgrass  Oeste    Bombilla        Hogar        14
# 328  22/1/2016  Trevor Snodgrass  Oeste    Bombilla        Hogar        14
# 69    5/1/2016  Trevor Snodgrass  Norte  Calcetines   Vestimenta         4
# 238  16/1/2016  Trevor Snodgrass    Sur      Shorts   Vestimenta         2
#
#     Ganancia
# 93      0,96
# 450     1,44
# 259     1,50
# ...

# %%
ventasTotales.Artículo=='Gorras'
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 455    False
# 456    False
# 457    False
# 458    False
# 459    False
# Name: Artículo, Length: 460, dtype: bool

# %%
ventasTotales[ventasTotales.Artículo=='Gorras']
# Out:
#          Fecha          Vendedor Región Artículo   Categoría  Unidades  \
# 2     1/1/2016        Sarah Bond    Sur   Gorras  Vestimenta         3
# 7     1/1/2016      Steve Ashton  Oeste   Gorras  Vestimenta         2
# 38    4/1/2016      Steve Ashton  Oeste   Gorras  Vestimenta        13
# 57    4/1/2016        Dustin Gee   Este   Gorras  Vestimenta         2
# 85    6/1/2016        Sarah Bond  Norte   Gorras  Vestimenta         9
# 156  10/1/2016  Trevor Snodgrass  Norte   Gorras  Vestimenta         7
# 159  11/1/2016      Steve Ashton  Norte   Gorras  Vestimenta         2
# 170  11/1/2016        Sarah Bond   Este   Gorras  Vestimenta         9
# 186  12/1/2016        Sarah Bond   Este   Gorras  Vestimenta        11
# 187  12/1/2016        Dustin Gee    Sur   Gorras  Vestimenta        13
# 201  14/1/2016   Desmond Delaney  Norte   Gorras  Vestimenta         5
# 231  15/1/2016  Trevor Snodgrass   Este   Gorras  Vestimenta         4
# ...

# %%
ventasTotales[(ventasTotales.Artículo=='Gorras')&(ventasTotales.Región=='Norte')]
# Out:
#          Fecha          Vendedor Región Artículo   Categoría  Unidades  \
# 85    6/1/2016        Sarah Bond  Norte   Gorras  Vestimenta         9
# 156  10/1/2016  Trevor Snodgrass  Norte   Gorras  Vestimenta         7
# 159  11/1/2016      Steve Ashton  Norte   Gorras  Vestimenta         2
# 201  14/1/2016   Desmond Delaney  Norte   Gorras  Vestimenta         5
# 360  25/1/2016      Steve Ashton  Norte   Gorras  Vestimenta         7
# 368  26/1/2016    Boris Stanford  Norte   Gorras  Vestimenta         7
# 394  27/1/2016      Steve Ashton  Norte   Gorras  Vestimenta        14
# 396  27/1/2016  Trevor Snodgrass  Norte   Gorras  Vestimenta         3
#
#     Ganancia
# 85     18,90
# 156    14,70
# 159     4,20
# 201    10,50
# 360    14,70
# 368    14,70
# 394    29,40
# 396     6,30

# %%
ventasTotales.Vendedor.str.contains('Trevor')
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 455    False
# 456    False
# 457    False
# 458    False
# 459     True
# Name: Vendedor, Length: 460, dtype: bool

# %%
ventasTotales[ventasTotales.Vendedor.str.contains('Trevor')]
# Out:
#          Fecha          Vendedor Región    Artículo    Categoría  Unidades  \
# 1     1/1/2016  Trevor Snodgrass  Oeste   Chocolate  Comestibles         8
# 5     1/1/2016  Trevor Snodgrass   Este     Cerveza  Comestibles        15
# 8     1/1/2016  Trevor Snodgrass   Este         Pan  Comestibles        12
# 10    1/1/2016  Trevor Snodgrass    Sur         Pan  Comestibles         6
# 12    1/1/2016  Trevor Snodgrass    Sur      Shorts   Vestimenta         6
# ..         ...               ...    ...         ...          ...       ...
# 437  30/1/2016  Trevor Snodgrass   Este  Calcetines   Vestimenta        10
# 440  30/1/2016  Trevor Snodgrass   Este      Gorras   Vestimenta         6
# 442  31/1/2016  Trevor Snodgrass   Este   Sandalias   Vestimenta         6
# 446  31/1/2016  Trevor Snodgrass  Oeste    Sudadera   Vestimenta         2
# 459  31/1/2016  Trevor Snodgrass    Sur   Pepinillo  Comestibles         7
#
#     Ganancia
# 1       3,84
# 5       6,00
# 8       4,80
# ...

# %%
ventasTotales[ventasTotales.Vendedor.str.startswith('T')]
# Out:
#          Fecha          Vendedor Región    Artículo    Categoría  Unidades  \
# 1     1/1/2016  Trevor Snodgrass  Oeste   Chocolate  Comestibles         8
# 5     1/1/2016  Trevor Snodgrass   Este     Cerveza  Comestibles        15
# 8     1/1/2016  Trevor Snodgrass   Este         Pan  Comestibles        12
# 10    1/1/2016  Trevor Snodgrass    Sur         Pan  Comestibles         6
# 12    1/1/2016  Trevor Snodgrass    Sur      Shorts   Vestimenta         6
# ..         ...               ...    ...         ...          ...       ...
# 437  30/1/2016  Trevor Snodgrass   Este  Calcetines   Vestimenta        10
# 440  30/1/2016  Trevor Snodgrass   Este      Gorras   Vestimenta         6
# 442  31/1/2016  Trevor Snodgrass   Este   Sandalias   Vestimenta         6
# 446  31/1/2016  Trevor Snodgrass  Oeste    Sudadera   Vestimenta         2
# 459  31/1/2016  Trevor Snodgrass    Sur   Pepinillo  Comestibles         7
#
#     Ganancia
# 1       3,84
# 5       6,00
# 8       4,80
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ali = ventasTotales.Categoría == 'Comestibles'

# %%
ali
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 455    False
# 456    False
# 457     True
# 458    False
# 459     True
# Name: Categoría, Length: 460, dtype: bool

# %%
ali = ventasTotales[ventasTotales.Categoría == 'Comestibles']

# %%
ali.head()
# Out:
#       Fecha          Vendedor Región           Artículo    Categoría  \
# 1  1/1/2016  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 3  1/1/2016   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4  1/1/2016   Desmond Delaney   Este          Chocolate  Comestibles
# 5  1/1/2016  Trevor Snodgrass   Este            Cerveza  Comestibles
# 6  1/1/2016    Boris Stanford  Norte          Pepinillo  Comestibles
#
#    Unidades Ganancia
# 1         8     3,84
# 3         9    14,40
# 4        14     6,72
# 5        15     6,00
# 6        14     4,20

# %%
ali.Artículo.value_counts()
# Out:
# Artículo
# Pan                  26
# Chocolate            25
# Sánguche de Queso    25
# Pepinillo            24
# Soda                 19
# Cerveza              17
# Caramelos            17
# Name: count, dtype: int64

# %%
ali.Artículo.value_counts().plot(kind='line', figsize=(10,5));

# %%
ali.Artículo.value_counts().plot(kind='bar', color='red');

# %%
ali.Artículo.value_counts().plot(kind='barh');

# %%
ali.Artículo.value_counts().plot(kind='pie', colormap='ocean');

# %%
ventasTotales.plot(kind='scatter', x='Ganancia', y='Unidades');

# %%
ventasTotales.set_index('Vendedor', inplace=True)

# %%
ventasTotales.head()
# Out:
#                      Fecha Región           Artículo    Categoría  Unidades  \
# Vendedor
# Steve Ashton      1/1/2016  Norte   Medias Femeninas   Vestimenta         6
# Trevor Snodgrass  1/1/2016  Oeste          Chocolate  Comestibles         8
# Sarah Bond        1/1/2016    Sur             Gorras   Vestimenta         3
# Desmond Delaney   1/1/2016    Sur  Sánguche de Queso  Comestibles         9
# Desmond Delaney   1/1/2016   Este          Chocolate  Comestibles        14
#
#                  Ganancia
# Vendedor
# Steve Ashton        18,00
# Trevor Snodgrass     3,84
# Sarah Bond           6,30
# Desmond Delaney     14,40
# Desmond Delaney      6,72

# %%
ventasTotales.reset_index(inplace=True)

# %%
ventasTotales.head()
# Out:
#            Vendedor     Fecha Región           Artículo    Categoría  \
# 0      Steve Ashton  1/1/2016  Norte   Medias Femeninas   Vestimenta
# 1  Trevor Snodgrass  1/1/2016  Oeste          Chocolate  Comestibles
# 2        Sarah Bond  1/1/2016    Sur             Gorras   Vestimenta
# 3   Desmond Delaney  1/1/2016    Sur  Sánguche de Queso  Comestibles
# 4   Desmond Delaney  1/1/2016   Este          Chocolate  Comestibles
#
#    Unidades Ganancia
# 0         6    18,00
# 1         8     3,84
# 2         3     6,30
# 3         9    14,40
# 4        14     6,72

# %%
ven = ventasTotales.set_index('Vendedor')

# %%
ven.head()
# Out:
#                      Fecha Región           Artículo    Categoría  Unidades  \
# Vendedor
# Steve Ashton      1/1/2016  Norte   Medias Femeninas   Vestimenta         6
# Trevor Snodgrass  1/1/2016  Oeste          Chocolate  Comestibles         8
# Sarah Bond        1/1/2016    Sur             Gorras   Vestimenta         3
# Desmond Delaney   1/1/2016    Sur  Sánguche de Queso  Comestibles         9
# Desmond Delaney   1/1/2016   Este          Chocolate  Comestibles        14
#
#                  Ganancia
# Vendedor
# Steve Ashton        18,00
# Trevor Snodgrass     3,84
# Sarah Bond           6,30
# Desmond Delaney     14,40
# Desmond Delaney      6,72

# %%
ven.sort_index(inplace=True)

# %%
ven.head()
# Out:
#                     Fecha Región    Artículo    Categoría  Unidades Ganancia
# Vendedor
# Boris Stanford  13/1/2016    Sur      Escoba        Hogar         1     3,65
# Boris Stanford   5/1/2016    Sur      Shorts   Vestimenta         1     4,90
# Boris Stanford   5/1/2016   Este  Escobillón        Hogar         8     6,80
# Boris Stanford  18/1/2016    Sur   Pepinillo  Comestibles         5     1,50
# Boris Stanford   5/1/2016    Sur         Pan  Comestibles         4     1,60

# %%
ventasTotales.set_index('Vendedor', inplace=True)
ventasTotales.head()
# Out:
#                      Fecha Región           Artículo    Categoría  Unidades  \
# Vendedor
# Steve Ashton      1/1/2016  Norte   Medias Femeninas   Vestimenta         6
# Trevor Snodgrass  1/1/2016  Oeste          Chocolate  Comestibles         8
# Sarah Bond        1/1/2016    Sur             Gorras   Vestimenta         3
# Desmond Delaney   1/1/2016    Sur  Sánguche de Queso  Comestibles         9
# Desmond Delaney   1/1/2016   Este          Chocolate  Comestibles        14
#
#                  Ganancia
# Vendedor
# Steve Ashton        18,00
# Trevor Snodgrass     3,84
# Sarah Bond           6,30
# Desmond Delaney     14,40
# Desmond Delaney      6,72

# %%
ventasTotales.loc['Sarah Bond']
# Out:
#                 Fecha Región    Artículo    Categoría  Unidades Ganancia
# Vendedor
# Sarah Bond   1/1/2016    Sur      Gorras   Vestimenta         3     6,30
# Sarah Bond   1/1/2016   Este   Caramelos  Comestibles        15     9,00
# Sarah Bond   2/1/2016  Norte     Bufanda   Vestimenta         4    11,00
# Sarah Bond   2/1/2016   Este      Escoba        Hogar        12    43,80
# Sarah Bond   4/1/2016    Sur  Detergente        Hogar        11    27,28
# ...               ...    ...         ...          ...       ...      ...
# Sarah Bond  29/1/2016   Este      Gorras   Vestimenta         7    14,70
# Sarah Bond  29/1/2016  Oeste  Detergente        Hogar         3     7,44
# Sarah Bond  31/1/2016    Sur  Calcetines   Vestimenta         7    15,75
# Sarah Bond  31/1/2016  Norte    Bombilla        Hogar         4     2,40
# Sarah Bond  31/1/2016    Sur     Bufanda   Vestimenta         6    16,50
#
# [86 rows x 6 columns]

# %%
ventasTotales.reset_index(inplace=True)

# %%
ventasTotales.loc[ventasTotales.Vendedor == 'Sarah Bond']
# Out:
#        Vendedor      Fecha Región    Artículo    Categoría  Unidades Ganancia
# 2    Sarah Bond   1/1/2016    Sur      Gorras   Vestimenta         3     6,30
# 9    Sarah Bond   1/1/2016   Este   Caramelos  Comestibles        15     9,00
# 23   Sarah Bond   2/1/2016  Norte     Bufanda   Vestimenta         4    11,00
# 27   Sarah Bond   2/1/2016   Este      Escoba        Hogar        12    43,80
# 42   Sarah Bond   4/1/2016    Sur  Detergente        Hogar        11    27,28
# ..          ...        ...    ...         ...          ...       ...      ...
# 426  Sarah Bond  29/1/2016   Este      Gorras   Vestimenta         7    14,70
# 427  Sarah Bond  29/1/2016  Oeste  Detergente        Hogar         3     7,44
# 443  Sarah Bond  31/1/2016    Sur  Calcetines   Vestimenta         7    15,75
# 453  Sarah Bond  31/1/2016  Norte    Bombilla        Hogar         4     2,40
# 455  Sarah Bond  31/1/2016    Sur     Bufanda   Vestimenta         6    16,50
#
# [86 rows x 7 columns]

# %%
ventasTotales.iloc[231]
# Out:
# Vendedor     Trevor Snodgrass
# Fecha               15/1/2016
# Región                   Este
# Artículo               Gorras
# Categoría          Vestimenta
# Unidades                    4
# Ganancia                 8,40
# Name: 231, dtype: object

# %%
ventasTotales.iloc[[231,49,162,101]]
# Out:
#              Vendedor      Fecha Región          Artículo   Categoría  \
# 231  Trevor Snodgrass  15/1/2016   Este            Gorras  Vestimenta
# 49         Sarah Bond   4/1/2016  Norte            Shorts  Vestimenta
# 162    Boris Stanford  11/1/2016   Este  Medias Femeninas  Vestimenta
# 101      Steve Ashton   7/1/2016  Oeste            Escoba       Hogar
#
#      Unidades Ganancia
# 231         4     8,40
# 49         12    58,80
# 162         5    15,00
# 101        13    47,45

# %%
    ventasTotales.iloc[7:14]
# Out:
#             Vendedor     Fecha Región    Artículo    Categoría  Unidades  \
# 7       Steve Ashton  1/1/2016  Oeste      Gorras   Vestimenta         2
# 8   Trevor Snodgrass  1/1/2016   Este         Pan  Comestibles        12
# 9         Sarah Bond  1/1/2016   Este   Caramelos  Comestibles        15
# 10  Trevor Snodgrass  1/1/2016    Sur         Pan  Comestibles         6
# 11    Boris Stanford  1/1/2016  Oeste  Calcetines   Vestimenta         7
# 12  Trevor Snodgrass  1/1/2016    Sur      Shorts   Vestimenta         6
# 13      Steve Ashton  2/1/2016   Este  Detergente        Hogar         7
#
#    Ganancia
# 7      4,20
# 8      4,80
# 9      9,00
# 10     2,40
# 11    15,75
# 12    29,40
# 13    17,36

# %%
    ventasTotales.groupby('Región')

# %%
list(ventasTotales.groupby('Región'))
# Out:
# [('Este',
#                Vendedor      Fecha Región           Artículo    Categoría  \
#   4     Desmond Delaney   1/1/2016   Este          Chocolate  Comestibles
#   5    Trevor Snodgrass   1/1/2016   Este            Cerveza  Comestibles
#   8    Trevor Snodgrass   1/1/2016   Este                Pan  Comestibles
#   9          Sarah Bond   1/1/2016   Este          Caramelos  Comestibles
#   13       Steve Ashton   2/1/2016   Este         Detergente        Hogar
#   ..                ...        ...    ...                ...          ...
#   447   Desmond Delaney  31/1/2016   Este           Bombilla        Hogar
#   449    Boris Stanford  31/1/2016   Este           Sudadera   Vestimenta
#   450    Boris Stanford  31/1/2016   Este          Chocolate  Comestibles
#   456        Dustin Gee  31/1/2016   Este          Sandalias   Vestimenta
#   457        Dustin Gee  31/1/2016   Este  Sánguche de Queso  Comestibles
#
#        Unidades Ganancia
#   4          14     6,72
# ...

# %%
for group_key, group_value in ventasTotales.groupby('Región'):
    print(group_key)
    print(group_value)
# Out:
# Este
#              Vendedor      Fecha Región           Artículo    Categoría  \
# 4     Desmond Delaney   1/1/2016   Este          Chocolate  Comestibles
# 5    Trevor Snodgrass   1/1/2016   Este            Cerveza  Comestibles
# 8    Trevor Snodgrass   1/1/2016   Este                Pan  Comestibles
# 9          Sarah Bond   1/1/2016   Este          Caramelos  Comestibles
# 13       Steve Ashton   2/1/2016   Este         Detergente        Hogar
# ..                ...        ...    ...                ...          ...
# 447   Desmond Delaney  31/1/2016   Este           Bombilla        Hogar
# 449    Boris Stanford  31/1/2016   Este           Sudadera   Vestimenta
# 450    Boris Stanford  31/1/2016   Este          Chocolate  Comestibles
# 456        Dustin Gee  31/1/2016   Este          Sandalias   Vestimenta
# 457        Dustin Gee  31/1/2016   Este  Sánguche de Queso  Comestibles
#
#      Unidades Ganancia
# 4          14     6,72
# 5          15     6,00
# 8          12     4,80
# ...

# %%
ventasTotales.groupby('Región').size()
# Out:
# Región
# Este     138
# Norte    100
# Oeste    102
# Sur      120
# dtype: int64

# %%
ventasTotales.groupby(['Región', 'Vendedor', 'Ganancia']).agg({'Región': ['min','max','count']})
# Out:
#                                  Región
#                                     min   max count
# Región Vendedor         Ganancia
# Este   Boris Stanford   1,44       Este  Este     1
#                         1,60       Este  Este     1
#                         15,00      Este  Este     1
#                         24,50      Este  Este     1
#                         24,75      Este  Este     1
# ...                                 ...   ...   ...
# Sur    Trevor Snodgrass 4,20        Sur   Sur     1
#                         4,32        Sur   Sur     1
#                         40,15       Sur   Sur     1
#                         7,20        Sur   Sur     1
#                         9,80        Sur   Sur     1
#
# [427 rows x 3 columns]

# %%
ventasTotales.loc[ventasTotales.Vendedor == 'Sarah Bond'].groupby('Vendedor').agg({'Ganancia' : ['min', 'max']})
# Out:
#            Ganancia
#                 min   max
# Vendedor
# Sarah Bond     0,60  9,80

# %%
cat = ventasTotales[(ventasTotales.Vendedor == 'Sarah Bond') & ((ventasTotales.Categoría == 'Vestimenta')|(ventasTotales.Categoría == 'Comestibles'))]
cat
# Out:
#        Vendedor      Fecha Región           Artículo    Categoría  Unidades  \
# 2    Sarah Bond   1/1/2016    Sur             Gorras   Vestimenta         3
# 9    Sarah Bond   1/1/2016   Este          Caramelos  Comestibles        15
# 23   Sarah Bond   2/1/2016  Norte            Bufanda   Vestimenta         4
# 48   Sarah Bond   4/1/2016   Este             Shorts   Vestimenta         2
# 49   Sarah Bond   4/1/2016  Norte             Shorts   Vestimenta        12
# 58   Sarah Bond   4/1/2016   Este            Bufanda   Vestimenta        14
# 62   Sarah Bond   5/1/2016  Norte            Cerveza  Comestibles         3
# 65   Sarah Bond   5/1/2016  Norte                Pan  Comestibles         3
# 85   Sarah Bond   6/1/2016  Norte             Gorras   Vestimenta         9
# 89   Sarah Bond   6/1/2016    Sur            Cerveza  Comestibles        15
# 104  Sarah Bond   7/1/2016   Este         Calcetines   Vestimenta        13
# ...

# %%
c = cat.groupby(['Artículo', 'Categoría', 'Región']).size()

# %%
c
# Out:
# Artículo           Categoría    Región
# Bufanda            Vestimenta   Este      2
#                                 Norte     1
#                                 Sur       2
# Calcetines         Vestimenta   Este      1
#                                 Norte     2
#                                 Oeste     2
#                                 Sur       1
# Caramelos          Comestibles  Este      1
#                                 Norte     2
# Cerveza            Comestibles  Este      2
#                                 Norte     2
#                                 Sur       1
# Chocolate          Comestibles  Este      1
#                                 Norte     2
#                                 Oeste     1
#                                 Sur       2
# Gorras             Vestimenta   Este      4
#                                 Norte     1
#                                 Sur       1
# Medias Femeninas   Vestimenta   Este      1
# ...

# %%
df = c.unstack('Región')
df
# Out:
# Región                         Este  Norte  Oeste  Sur
# Artículo          Categoría
# Bufanda           Vestimenta    2.0    1.0    NaN  2.0
# Calcetines        Vestimenta    1.0    2.0    2.0  1.0
# Caramelos         Comestibles   1.0    2.0    NaN  NaN
# Cerveza           Comestibles   2.0    2.0    NaN  1.0
# Chocolate         Comestibles   1.0    2.0    1.0  2.0
# Gorras            Vestimenta    4.0    1.0    NaN  1.0
# Medias Femeninas  Vestimenta    1.0    1.0    NaN  NaN
# Pan               Comestibles   NaN    2.0    NaN  4.0
# Pepinillo         Comestibles   1.0    1.0    1.0  1.0
# Sandalias         Vestimenta    NaN    NaN    1.0  1.0
# Shorts            Vestimenta    3.0    1.0    NaN  NaN
# Soda              Comestibles   NaN    NaN    1.0  2.0
# Sudadera          Vestimenta    1.0    NaN    NaN  1.0
# Sánguche de Queso Comestibles   2.0    1.0    NaN  NaN

# %%
df.stack()
# Out:
# Artículo           Categoría    Región
# Bufanda            Vestimenta   Este      2.0
#                                 Norte     1.0
#                                 Sur       2.0
# Calcetines         Vestimenta   Este      1.0
#                                 Norte     2.0
#                                 Oeste     2.0
#                                 Sur       1.0
# Caramelos          Comestibles  Este      1.0
#                                 Norte     2.0
# Cerveza            Comestibles  Este      2.0
#                                 Norte     2.0
#                                 Sur       1.0
# Chocolate          Comestibles  Este      1.0
#                                 Norte     2.0
#                                 Oeste     1.0
#                                 Sur       2.0
# Gorras             Vestimenta   Este      4.0
#                                 Norte     1.0
#                                 Sur       1.0
# ...

# %%
df.stack('Región')
# Out:
# Artículo           Categoría    Región
# Bufanda            Vestimenta   Este      2.0
#                                 Norte     1.0
#                                 Sur       2.0
# Calcetines         Vestimenta   Este      1.0
#                                 Norte     2.0
#                                 Oeste     2.0
#                                 Sur       1.0
# Caramelos          Comestibles  Este      1.0
#                                 Norte     2.0
# Cerveza            Comestibles  Este      2.0
#                                 Norte     2.0
#                                 Sur       1.0
# Chocolate          Comestibles  Este      1.0
#                                 Norte     2.0
#                                 Oeste     1.0
#                                 Sur       2.0
# Gorras             Vestimenta   Este      4.0
#                                 Norte     1.0
#                                 Sur       1.0
# ...

# %%
df.unstack('Categoría')
# Out:
# Región                   Este                  Norte                  Oeste  \
# Categoría         Comestibles Vestimenta Comestibles Vestimenta Comestibles
# Artículo
# Bufanda                   NaN        2.0         NaN        1.0         NaN
# Calcetines                NaN        1.0         NaN        2.0         NaN
# Caramelos                 1.0        NaN         2.0        NaN         NaN
# Cerveza                   2.0        NaN         2.0        NaN         NaN
# Chocolate                 1.0        NaN         2.0        NaN         1.0
# Gorras                    NaN        4.0         NaN        1.0         NaN
# Medias Femeninas          NaN        1.0         NaN        1.0         NaN
# Pan                       NaN        NaN         2.0        NaN         NaN
# Pepinillo                 1.0        NaN         1.0        NaN         1.0
# Sandalias                 NaN        NaN         NaN        NaN         NaN
# ...
